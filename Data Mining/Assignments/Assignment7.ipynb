# %% [markdown]
# # Assignment 7
# by [Jay Nakum](https://jaynakum.github.io) [20BCP304D]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./datasets/Credit Card Dataset for Clustering.csv')
data.head()

# %%
data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].mean(),inplace=True)
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].mean(),inplace=True)

# %%
data.isna().any()

# %%
fig = plt.figure(figsize=(30, 30), dpi=300)
mat = data.corr()
sns.heatmap(mat, annot=True);

# %%
X=data.drop('CUST_ID',axis=1)
X

# %%
from sklearn.preprocessing import StandardScaler
sca=StandardScaler()
X=sca.fit_transform(X)
X

# %%
from sklearn.cluster import KMeans

# %%
n=[]
for i in range(1,11):
    kmean = KMeans(n_clusters=i, random_state=0)
    kmean.fit(X)
    n.append(kmean.inertia_)
plt.plot(range(1,11),n)
plt.title('Elbow Method')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
from yellowbrick.cluster import SilhouetteVisualizer
fig, ax = plt.subplots(3,3, figsize=(15,8))
ax = ax.ravel() #ax is 2D ravel will convert it into 1D
plt.subplots_adjust(hspace=0.4)
m=0
for i in [2,3,4,5,6,7,8,9,10]:
    km=KMeans(n_clusters=i, init='k-means++', random_state=0)
    ax[m].set_title("No. of Clusters.{}".format(i))
    vis=SilhouetteVisualizer(km, ax=ax[m])
    m=m+1
    vis.fit(X)

# %%
model=KMeans(n_clusters=3, random_state=0)
y=model.fit_predict(X)
from sklearn.metrics import silhouette_score
silhouette_score(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\.git\Python\Data Mining\Assignment7.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/.git/Python/Data%20Mining/Assignment7.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> model=KMeans(n_clusters=3, random_state=0)
#       <a href='vscode-notebook-cell:/d%3A/.git/Python/Data%20Mining/Assignment7.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> y=model.fit_predict(X)
#       <a href='vscode-notebook-cell:/d%3A/.git/Python/Data%20Mining/Assignment7.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.metrics import silhouette_score
#
# NameError: name 'KMeans' is not defined
